# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Examine the data
data=pd.read_csv("dataset_risk_analytics.csv")
data
# Out:
#       loan_id  monthly_income  origination_score_band  TOB_months  \
# 0        1000          6000.0                       5        83.0
# 1        1001         39000.0                       5        82.0
# 2        1002         18000.0                       5        78.0
# 3        1003         23250.0                       3        76.0
# 4        1004         12000.0                       3        74.0
# ...       ...             ...                     ...         ...
# 5778     6245          8250.0                       4         6.0
# 5779     6246          2250.0                       5         6.0
# 5780     6247          3750.0                       5         6.0
# 5781     6248          9750.0                       7         6.0
# 5782     6249          2250.0                       6         6.0
#
#       closing_principal_balance  original_loan_amount product  \
# 0                         300.0                1800.0       B
# 1                        7200.0               11700.0       B
# 2                        2700.0                5400.0       B
# 3                        3900.0                6900.0       B
# 4                        2100.0                3600.0       B
# ...                         ...                   ...     ...
# 5778                     6000.0                6000.0       A
# 5779                     1500.0                1500.0       C
# 5780                     3000.0                3000.0       D
# 5781                     7500.0                7500.0       D
# 5782                     1500.0                1500.0       C
#
#       original_loan_term  remaining_loan_term delq_history  target
# 0                     24                    5  0,0,0,0,0,0       0
# 1                     60                   42  0,1,0,0,0,0       0
# 2                     60                   46  0,0,1,0,0,0       0
# 3                     60                   48  1,1,0,1,0,0       1
# 4                     60                   50  1,0,0,0,0,0       0
# ...                  ...                  ...          ...     ...
# 5778                  36                   35  0,0,0,0,0,0       0
# 5779                  12                   11  0,0,0,0,0,0       0
# 5780                  60                   65  0,0,0,0,0,0       0
# 5781                  60                   65  0,0,0,0,0,0       1
# 5782                  36                   35  0,0,0,0,0,0       0
#
# [5783 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5783 entries, 0 to 5782
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    5783 non-null   int64
#  1   monthly_income             5406 non-null   float64
#  2   origination_score_band     5783 non-null   int64
#  3   TOB_months                 5406 non-null   float64
#  4   closing_principal_balance  5406 non-null   float64
#  5   original_loan_amount       5406 non-null   float64
#  6   product                    5783 non-null   object
#  7   original_loan_term         5783 non-null   int64
#  8   remaining_loan_term        5783 non-null   int64
#  9   delq_history               5406 non-null   object
#  10  target                     5783 non-null   int64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 497.1+ KB

# %%
data.describe()
# Out:
#            loan_id  monthly_income  origination_score_band   TOB_months  \
# count  5783.000000     5406.000000             5783.000000  5406.000000
# mean   3625.042711    14314.372919                3.904029    28.385683
# std    1516.292643    13799.514988                1.490877    16.357494
# min    1000.000000      750.000000                1.000000     6.000000
# 25%    2310.500000     6000.000000                3.000000    17.000000
# 50%    3623.000000     9750.000000                4.000000    24.000000
# 75%    4934.500000    17250.000000                5.000000    38.000000
# max    6249.000000    99750.000000                8.000000    83.000000
#
#        closing_principal_balance  original_loan_amount  original_loan_term  \
# count                5406.000000           5406.000000         5783.000000
# mean                 5714.391417           6630.701073           62.023517
# std                  7837.483534           8491.265603           23.774170
# min                   100.000000            100.000000           12.000000
# 25%                  1380.000000           1800.000000           60.000000
# 50%                  3000.000000           3750.000000           60.000000
# 75%                  6800.000000           8100.000000           60.000000
# max                 88200.000000          90000.000000          192.000000
#
#        remaining_loan_term       target
# count          5783.000000  5783.000000
# mean             39.618364     0.302092
# std              25.004423     0.459205
# min               0.000000     0.000000
# 25%              23.000000     0.000000
# 50%              40.000000     0.000000
# 75%              51.000000     1.000000
# max             177.000000     1.000000

# %%
data.shape
# Out:
# (5783, 11)

# %%
# Clean data for(Outliers, null vales, duplicates)
data.isnull().sum()
# Out:
# loan_id                        0
# monthly_income               377
# origination_score_band         0
# TOB_months                   377
# closing_principal_balance    377
# original_loan_amount         377
# product                        0
# original_loan_term             0
# remaining_loan_term            0
# delq_history                 377
# target                         0
# dtype: int64

# %%
# percentage of null values
data.isnull().sum() * 100 / len(data)
# Out:
# loan_id                      0.000000
# monthly_income               6.519108
# origination_score_band       0.000000
# TOB_months                   6.519108
# closing_principal_balance    6.519108
# original_loan_amount         6.519108
# product                      0.000000
# original_loan_term           0.000000
# remaining_loan_term          0.000000
# delq_history                 6.519108
# target                       0.000000
# dtype: float64

# %%
#Show all rows with null values
data[data.isna().any(axis=1)]
# Out:
#       loan_id  monthly_income  origination_score_band  TOB_months  \
# 17       1016             NaN                       4         NaN
# 22       1021             NaN                       3         NaN
# 53       1049             NaN                       3         NaN
# 85       1077             NaN                       3         NaN
# 88       1079             NaN                       5         NaN
# ...       ...             ...                     ...         ...
# 5704     6174             NaN                       5         NaN
# 5717     6186             NaN                       2         NaN
# 5723     6192             NaN                       4         NaN
# 5729     6198             NaN                       5         NaN
# 5760     6227             NaN                       5         NaN
#
#       closing_principal_balance  original_loan_amount product  \
# 17                          NaN                   NaN       A
# 22                          NaN                   NaN       B
# 53                          NaN                   NaN       B
# 85                          NaN                   NaN       B
# 88                          NaN                   NaN       A
# ...                         ...                   ...     ...
# 5704                        NaN                   NaN       C
# 5717                        NaN                   NaN       C
# 5723                        NaN                   NaN       A
# 5729                        NaN                   NaN       C
# 5760                        NaN                   NaN       C
#
#       original_loan_term  remaining_loan_term delq_history  target
# 17                    60                    1          NaN       0
# 22                    60                    3          NaN       0
# 53                    60                   17          NaN       0
# 85                    60                   38          NaN       0
# 88                    60                   40          NaN       0
# ...                  ...                  ...          ...     ...
# 5704                  36                   23          NaN       1
# 5717                  42                   31          NaN       0
# 5723                  66                   58          NaN       0
# 5729                  39                   29          NaN       0
# 5760                  12                    6          NaN       0
#
# [377 rows x 11 columns]

# %%
#Show all rows with duplicated values
data[data.duplicated(keep=False)]
# Out:
#       loan_id  monthly_income  origination_score_band  TOB_months  \
# 10       1010         15000.0                       4        66.0
# 11       1010         15000.0                       4        66.0
# 28       1027          9750.0                       3        57.0
# 29       1027          9750.0                       3        57.0
# 33       1031          9000.0                       5        54.0
# ...       ...             ...                     ...         ...
# 5710     6179           750.0                       5        17.0
# 5732     6201          5250.0                       3        14.0
# 5733     6201          5250.0                       3        14.0
# 5740     6208          5250.0                       4        13.0
# 5741     6208          5250.0                       4        13.0
#
#       closing_principal_balance  original_loan_amount product  \
# 10                       2700.0                4500.0       B
# 11                       2700.0                4500.0       B
# 28                       2400.0                3000.0       B
# 29                       2400.0                3000.0       B
# 33                       2100.0                2700.0       A
# ...                         ...                   ...     ...
# 5710                      750.0                 750.0       C
# 5732                     3000.0                3750.0       C
# 5733                     3000.0                3750.0       C
# 5740                     1500.0                3750.0       C
# 5741                     1500.0                3750.0       C
#
#       original_loan_term  remaining_loan_term delq_history  target
# 10                    60                   58  0,0,0,0,0,0       0
# 11                    60                   58  0,0,0,0,0,0       0
# 28                    60                    7  0,0,0,0,0,0       0
# 29                    60                    7  0,0,0,0,0,0       0
# 33                    60                   10  0,0,0,0,0,0       1
# ...                  ...                  ...          ...     ...
# 5710                  36                   24  0,0,0,0,0,0       1
# 5732                  60                   51  0,0,2,1,1,0       0
# 5733                  60                   51  0,0,2,1,1,0       0
# 5740                  12                    4  0,0,0,0,0,0       0
# 5741                  12                    4  0,0,0,0,0,0       0
#
# [1066 rows x 11 columns]

# %%
#Drop all row with null values
data = data.dropna()
data
# Out:
#       loan_id  monthly_income  origination_score_band  TOB_months  \
# 0        1000          6000.0                       5        83.0
# 1        1001         39000.0                       5        82.0
# 2        1002         18000.0                       5        78.0
# 3        1003         23250.0                       3        76.0
# 4        1004         12000.0                       3        74.0
# ...       ...             ...                     ...         ...
# 5778     6245          8250.0                       4         6.0
# 5779     6246          2250.0                       5         6.0
# 5780     6247          3750.0                       5         6.0
# 5781     6248          9750.0                       7         6.0
# 5782     6249          2250.0                       6         6.0
#
#       closing_principal_balance  original_loan_amount product  \
# 0                         300.0                1800.0       B
# 1                        7200.0               11700.0       B
# 2                        2700.0                5400.0       B
# 3                        3900.0                6900.0       B
# 4                        2100.0                3600.0       B
# ...                         ...                   ...     ...
# 5778                     6000.0                6000.0       A
# 5779                     1500.0                1500.0       C
# 5780                     3000.0                3000.0       D
# 5781                     7500.0                7500.0       D
# 5782                     1500.0                1500.0       C
#
#       original_loan_term  remaining_loan_term delq_history  target
# 0                     24                    5  0,0,0,0,0,0       0
# 1                     60                   42  0,1,0,0,0,0       0
# 2                     60                   46  0,0,1,0,0,0       0
# 3                     60                   48  1,1,0,1,0,0       1
# 4                     60                   50  1,0,0,0,0,0       0
# ...                  ...                  ...          ...     ...
# 5778                  36                   35  0,0,0,0,0,0       0
# 5779                  12                   11  0,0,0,0,0,0       0
# 5780                  60                   65  0,0,0,0,0,0       0
# 5781                  60                   65  0,0,0,0,0,0       1
# 5782                  36                   35  0,0,0,0,0,0       0
#
# [5406 rows x 11 columns]

# %%
#Show all rows with null values
data[data.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [loan_id, monthly_income, origination_score_band, TOB_months, closing_principal_balance, original_loan_amount, product, original_loan_term, remaining_loan_term, delq_history, target]
# Index: []

# %%
# drop all rows with duplicate
data = data.drop_duplicates(keep='first')
data
# Out:
#       loan_id  monthly_income  origination_score_band  TOB_months  \
# 0        1000          6000.0                       5        83.0
# 1        1001         39000.0                       5        82.0
# 2        1002         18000.0                       5        78.0
# 3        1003         23250.0                       3        76.0
# 4        1004         12000.0                       3        74.0
# ...       ...             ...                     ...         ...
# 5778     6245          8250.0                       4         6.0
# 5779     6246          2250.0                       5         6.0
# 5780     6247          3750.0                       5         6.0
# 5781     6248          9750.0                       7         6.0
# 5782     6249          2250.0                       6         6.0
#
#       closing_principal_balance  original_loan_amount product  \
# 0                         300.0                1800.0       B
# 1                        7200.0               11700.0       B
# 2                        2700.0                5400.0       B
# 3                        3900.0                6900.0       B
# 4                        2100.0                3600.0       B
# ...                         ...                   ...     ...
# 5778                     6000.0                6000.0       A
# 5779                     1500.0                1500.0       C
# 5780                     3000.0                3000.0       D
# 5781                     7500.0                7500.0       D
# 5782                     1500.0                1500.0       C
#
#       original_loan_term  remaining_loan_term delq_history  target
# 0                     24                    5  0,0,0,0,0,0       0
# 1                     60                   42  0,1,0,0,0,0       0
# 2                     60                   46  0,0,1,0,0,0       0
# 3                     60                   48  1,1,0,1,0,0       1
# 4                     60                   50  1,0,0,0,0,0       0
# ...                  ...                  ...          ...     ...
# 5778                  36                   35  0,0,0,0,0,0       0
# 5779                  12                   11  0,0,0,0,0,0       0
# 5780                  60                   65  0,0,0,0,0,0       0
# 5781                  60                   65  0,0,0,0,0,0       1
# 5782                  36                   35  0,0,0,0,0,0       0
#
# [4873 rows x 11 columns]

# %%
#Verify all rows with duplicated values are dropped
data[data.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [loan_id, monthly_income, origination_score_band, TOB_months, closing_principal_balance, original_loan_amount, product, original_loan_term, remaining_loan_term, delq_history, target]
# Index: []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4873 entries, 0 to 5782
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4873 non-null   int64
#  1   monthly_income             4873 non-null   float64
#  2   origination_score_band     4873 non-null   int64
#  3   TOB_months                 4873 non-null   float64
#  4   closing_principal_balance  4873 non-null   float64
#  5   original_loan_amount       4873 non-null   float64
#  6   product                    4873 non-null   int64
#  7   original_loan_term         4873 non-null   int64
#  8   remaining_loan_term        4873 non-null   int64
#  9   delq_history               4873 non-null   int32
#  10  target                     4873 non-null   int64
# dtypes: float64(4), int32(1), int64(6)
# memory usage: 437.8 KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data.dtypes
# Out:
# loan_id                        int64
# monthly_income               float64
# origination_score_band         int64
# TOB_months                   float64
# closing_principal_balance    float64
# original_loan_amount         float64
# product                        int64
# original_loan_term             int64
# remaining_loan_term            int64
# delq_history                   int32
# target                         int64
# dtype: object

# %%
#create instance of label encoder
data_lab = LabelEncoder()

# %%
#perform label encoding on Product column
data['product'] = data_lab.fit_transform (data['product'])
# Out:
# C:\Users\karee\AppData\Local\Temp\ipykernel_28072\523820642.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['product'] = data_lab.fit_transform (data['product'])

# %%
#perform label encoding on delq_history column
data['delq_history'] =data_lab.fit_transform(data['delq_history'])
# Out:
# C:\Users\karee\AppData\Local\Temp\ipykernel_28072\3334265293.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['delq_history'] =data_lab.fit_transform(data['delq_history'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4873 entries, 0 to 5782
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4873 non-null   int64
#  1   monthly_income             4873 non-null   float64
#  2   origination_score_band     4873 non-null   int64
#  3   TOB_months                 4873 non-null   float64
#  4   closing_principal_balance  4873 non-null   float64
#  5   original_loan_amount       4873 non-null   float64
#  6   product                    4873 non-null   int64
#  7   original_loan_term         4873 non-null   int64
#  8   remaining_loan_term        4873 non-null   int64
#  9   delq_history               4873 non-null   int64
#  10  target                     4873 non-null   int64
# dtypes: float64(4), int64(7)
# memory usage: 456.8 KB

# %%
#Separate features and target into X and Y
x = data[['monthly_income', 'origination_score_band', 'product', 'original_loan_amount',
          'original_loan_term', 'remaining_loan_term']].values
x = x.reshape(-1,6)
x
# Out:
# array([[6.00e+03, 5.00e+00, 1.00e+00, 1.80e+03, 2.40e+01, 5.00e+00],
#        [3.90e+04, 5.00e+00, 1.00e+00, 1.17e+04, 6.00e+01, 4.20e+01],
#        [1.80e+04, 5.00e+00, 1.00e+00, 5.40e+03, 6.00e+01, 4.60e+01],
#        ...,
#        [3.75e+03, 5.00e+00, 3.00e+00, 3.00e+03, 6.00e+01, 6.50e+01],
#        [9.75e+03, 7.00e+00, 3.00e+00, 7.50e+03, 6.00e+01, 6.50e+01],
#        [2.25e+03, 6.00e+00, 2.00e+00, 1.50e+03, 3.60e+01, 3.50e+01]])

# %%
y =data['target'].values
y
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
# !pip3 install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.7.3-py3-none-win_amd64.whl (89.1 MB)
#      --------------------------------------- 89.1/89.1 MB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\karee\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\users\karee\anaconda3\lib\site-packages (from xgboost) (1.9.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.3

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_wine
X_train, X_test, y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=40)

# %%
x,y=load_wine(return_X_y=True, as_frame=True)

# %%
model = XGBClassifier(eval_metric='mlogloss')
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob',
#               predictor=None, ...)

# %%
y_predict = model.predict(X_test)
y_predict
# Out:
# array([1, 0, 0, 2, 2, 1, 0, 1, 1, 0, 1, 2, 0, 0, 1, 2, 2, 0, 1, 0, 2, 0,
#        1, 0, 2, 2, 0, 2, 2, 1, 0, 0, 2, 1, 2, 2, 1, 1, 1, 2, 2, 2, 1, 2,
#        0, 1, 1, 0, 1, 1, 2, 1, 0, 1], dtype=int64)

# %%
accuracy_score(y_test,y_predict) * 100
# Out:
# 96.29629629629629

# %%
from sklearn.metrics import confusion_matrix
#from sklearn.metrics import mean_squared_error
confusion_matrix(y_test, y_predict)
# Out:
# array([[15,  0,  0],
#        [ 1, 19,  0],
#        [ 0,  1, 18]], dtype=int64)
